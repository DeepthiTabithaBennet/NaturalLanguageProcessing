# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiTabithaBennet/NaturalLanguageProcessing/blob/main/SentimentAnalysis_EmailSpamHamDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dataset - https://www.kaggle.com/datasets/jackksoncsie/spam-email-dataset
# Code - https://www.kaggle.com/code/tossik/spam-classification

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from sklearn.naive_bayes import ComplementNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, classification_report

# %%
from google.colab import drive
drive.mount('/content/drive/')

data = pd.read_csv("/content/drive/MyDrive/NLP Datasets/emails.csv")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5728 entries, 0 to 5727
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5728 non-null   object
#  1   spam    5728 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 89.6+ KB

# %%
## Counting the null objects
data.isnull().sum()
# Out:
# text    0
# spam    0
# dtype: int64

# %%
# Checking for duplicated data
data.duplicated().sum()

# Removing duplicates
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %%
# Lowercasing the text
data['text'] = data['text'].str.lower()
data['text'].head()
# Out:
# 0    subject: naturally irresistible your corporate...
# 1    subject: the stock trading gunslinger  fanny i...
# 2    subject: unbelievable new homes made easy  im ...
# 3    subject: 4 color printing special  request add...
# 4    subject: do not have money , get software cds ...
# Name: text, dtype: object

# %%
# Removing "Subject: ", as it is the email template, not the email content
data['text'] = data['text'].str.replace('subject: ', '')
data['text'].head()
# Out:
# 0    naturally irresistible your corporate identity...
# 1    the stock trading gunslinger  fanny is merrill...
# 2    unbelievable new homes made easy  im wanting t...
# 3    4 color printing special  request additional i...
# 4    do not have money , get software cds from here...
# Name: text, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(data["text"], data["spam"], test_size=0.1, shuffle=True, random_state=1)

# %%
# Bag-of-Words
vectorizer = CountVectorizer()
vectorized = vectorizer.fit(data["text"])

train_vectorized_X = vectorizer.transform(X_train).toarray()
test_vectorized_X = vectorizer.transform(X_test).toarray()

# %%
naive_bayes = ComplementNB()
naive_bayes.fit(train_vectorized_X, y_train)
predictions = naive_bayes.predict(test_vectorized_X)

# %%
print(classification_report(y_test, predictions,  digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9977    0.9931    0.9954       436
#            1     0.9779    0.9925    0.9852       134
#
#     accuracy                         0.9930       570
#    macro avg     0.9878    0.9928    0.9903       570
# weighted avg     0.9931    0.9930    0.9930       570

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[433   3]
#  [  1 133]]
