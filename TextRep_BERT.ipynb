# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiTabithaBennet/NaturalLanguageProcessing/blob/main/TextRep_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import BertTokenizer

# Load pre-trained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")

# Input text
text = 'Hello wordl! Im Deepthi Tabitha Bennet, and Im a Final-Year Data Science Student'

# Tokenize and encode the text
encoding = tokenizer.encode(text)

# %%
# Print the token IDs
print("Token IDs:", encoding)
# Out:
# Token IDs: [101, 8667, 1937, 1233, 106, 146, 1306, 7786, 14298, 23856, 3096, 6097, 117, 1105, 146, 1306, 170, 3788, 118, 2381, 7154, 2444, 7646, 102]

# %%
# Convert token IDs back to tokens
tokens = tokenizer.convert_ids_to_tokens(encoding)

# Print the corresponding tokens
print("Tokens:", tokens)
# Out:
# Tokens: ['[CLS]', 'Hello', 'word', '##l', '!', 'I', '##m', 'Deep', '##thi', 'Tabitha', 'Ben', '##net', ',', 'and', 'I', '##m', 'a', 'Final', '-', 'Year', 'Data', 'Science', 'Student', '[SEP]']
